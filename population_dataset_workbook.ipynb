# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load dataset
df = pd.read_csv("world_population.csv")
# View first 5 rows
df.head()
# Plot global population trend
global_trend = df.groupby("Year")["Value"].sum()
plt.figure(figsize=(10,5))
plt.plot(global_trend.index, global_trend.values)
plt.title("Global Population Over Time")
plt.xlabel("Year")
plt.ylabel("Population")
plt.grid(True)
plt.show()

# %%
df.head()
# Out:
#   Country Name Country Code  Year    Value
# 0        Aruba          ABW  1960  54922.0
# 1        Aruba          ABW  1961  55578.0
# 2        Aruba          ABW  1962  56320.0
# 3        Aruba          ABW  1963  57002.0
# 4        Aruba          ABW  1964  57619.0

# %%
top5_countries = top_countries["Country Name"].tolist()
df_top5 = df[df["Country Name"].isin(top5_countries)]

for country in top5_countries:
    country_data = df_top5[df_top5["Country Name"] == country]
    plt.plot(country_data["Year"], country_data["Value"], label=country)

plt.title("Population Growth of Top 5 Countries")
plt.xlabel("Year")
plt.ylabel("Population")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 top5_countries = top_countries["Country Name"].tolist()
#       2 df_top5 = df[df["Country Name"].isin(top5_countries)]
#       4 for country in top5_countries:
#
# NameError: name 'top_countries' is not defined
